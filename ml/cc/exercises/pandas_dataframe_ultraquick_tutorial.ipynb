# %% [markdown]
# Exa API demo

# %%
from exa_py import Exa
exa = Exa(api_key="f0ce7d81-df07-4f64-8cbe-a7f90ce7d2e9")

result = exa.search(
  "周杰伦的夜曲销售量",
  num_results=3,
  type="auto",
  contents={
    "highlights": {
      "max_characters": 2000
    }
  }
)

print(result)
